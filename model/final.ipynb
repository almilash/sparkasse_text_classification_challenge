# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

import nltk
import spacy
from nltk.corpus import stopwords
from nltk.stem.snowball import GermanStemmer
#!pip install gensim
import gensim
import gensim.corpora as corpora
from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold, LeaveOneOut, cross_val_predict
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Pre-processing

# %%
nltk.download('stopwords')
stopwords_l = stopwords.words("german")

def tokenize(text):
    nltk.download('stopwords')
    stopwords_l = stopwords.words("german")
    tokens = gensim.utils.simple_preprocess(text, deacc=True)
    tokens = [token for token in tokens if token not in stopwords_l]
    return tokens



def clean_text(df: pd.DataFrame, x : str):

    df[x] = df[x].str.lower()
    df[x] = df[x].replace(r"^(.*?),","",regex= True)
    # df[x] = df[x].replace(r"(viele|mit|herzliche|liebe|beste|freundliche).*grüß.*", "", regex=True) # zu breit, fuehrt teilw zu fehlern
    df[x] = df[x].replace(
    r"(mit\s+(freundlichen?|besten?)\s+grüß\w*|"
    r"freundlich\w*\s+grüß\w*|"
    r"herzlich\w*\s+grüß\w*|"
    r"viel\w*\s+grüß\w*|"
    r"lieb\w*\s+grüß\w*|"
    r"beste\s+grüß\w*)\s*.*$",
    "",
    regex=True)
    df[x] = df[x].replace(r" bitte*", "", regex=True)
    df[x] = df[x].replace(r"vielen dank.*","",regex = True)
    df[x] = df[x].replace(r'[^\s\w]+','',regex = True)

    return df


def remove_stopwords_from_series(text):
    words = text.split()
    words_filtered = [w for w in words if w not in stopwords_l]
    return " ".join(words_filtered)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df = pd.read_excel("20250602_Anfragen_Sample.xlsx")
df_clean = clean_text(df, "Kundenanfrage")
df_clean["Kundenanfrage"] = df_clean["Kundenanfrage"].apply(remove_stopwords_from_series)
df_clean["tokens"] = df_clean["Kundenanfrage"].str.split()
id2word = corpora.Dictionary(df_clean["tokens"])
texts = df_clean["tokens"]
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # Descriptive Figures

# %%
df = pd.read_excel("20250602_Anfragen_Sample.xlsx")
df["text_length"] = df["Kundenanfrage"].apply(lambda x: len(str(x).split()))
df_clean["text_length"] = df_clean["Kundenanfrage"].apply(lambda x: len(str(x).split()))
df["state"] = "before"
df_clean["state"] = "after"
df_comb = pd.concat([df, df_clean])

sns.set(font_scale=1.2)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_comb,x='Unterkategorie2', y='text_length',hue='state',dodge=False)
plt.xticks(rotation=45, ha='right')
plt.title('Inquiry length before / after preprocessing')
plt.tight_layout()
plt.show()

# %%
from collections import Counter, defaultdict
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

all_tokens = df_clean["tokens"].explode()
word_counts = Counter(all_tokens)

topwords = [word for word, _ in word_counts.most_common(10)]
categories = df_clean["Unterkategorie2"].unique()
heatmap_data = pd.DataFrame(0, index=topwords, columns=categories)

for _, row in df_clean.iterrows():
    tokens = row["tokens"]
    category = row["Unterkategorie2"]
    for token in tokens:
        if token in topwords:
            heatmap_data.at[token, category] += 1

plt.figure(figsize=(15, 10))
sns.heatmap(heatmap_data, annot=True, annot_kws={"size": 16}, cmap='Greens')
plt.xticks(fontsize=20, rotation=90)
plt.yticks(fontsize=20, rotation=0)
plt.tight_layout()
plt.show()

# %%
# word clouds
df_group = pd.DataFrame(df_clean.groupby("Unterkategorie2")["Kundenanfrage"].agg(lambda x: " ".join(x))) #combine each category
wordcloud_dic = {}
for index,row in df_group.iterrows():
    wc = WordCloud(background_color='white', colormap = 'binary').generate(row["Kundenanfrage"])
    wordcloud_dic[index] = wc
for k,v in wordcloud_dic.items():
    print(k)
    plt.axis("off")
    plt.imshow(v)
    plt.show()
# Out:
# Adressänderung
# Auslandsbuchung
# Bearbeitungsdauer
# Gebühren
# Gerätewechsel
# Girokonto
# Kreditkarte
# Nachhaltige Geldanlagen
# Namensänderung
# Phishing
# Servicequalität
# TAN-Verfahren

# %% [markdown]
# # Logistic Regression with TF-IDF

# %%
x = df_clean["Kundenanfrage"].astype(str)
y = df_clean["Unterkategorie2"].astype(str)

pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(
        max_features=1000,
        ngram_range=(1, 2),
        min_df=0.01,
        max_df=0.8
    )),
    ("lr", LogisticRegression(max_iter=2000))
])

param1 = {
    'lr__C': [0.01, 0.1, 1, 10],
    'lr__penalty': ['l1','l2'],
    'lr__solver': ['liblinear'],
    'lr__class_weight': [None, 'balanced'],
    'lr__multi_class': ['ovr']
}

param2 = {
    'lr__C': [0.01, 0.1, 1, 10],
    'lr__penalty': ['l2'], # lbfgs nur mit L2 (oder none)
    'lr__solver': ['lbfgs', 'newton-cg'],
    'lr__class_weight': [None, 'balanced'],
    'lr__multi_class': ['ovr']
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param2,
    cv=LeaveOneOut(),
    scoring='accuracy',
    #scoring='f1_macro',
    n_jobs=-1
)
grid.fit(x, y)

best_lr = grid.best_estimator_
print("best params", grid.best_params_)
print("mean acc", grid.best_score_)

y_pred_loo = cross_val_predict(best_lr, x, y, cv=LeaveOneOut(), n_jobs=-1)
print(classification_report(y, y_pred_loo))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# best params {'lr__C': 1, 'lr__class_weight': 'balanced', 'lr__multi_class': 'ovr', 'lr__penalty': 'l2', 'lr__solver': 'lbfgs'}
# mean acc 0.963855421686747
#                          precision    recall  f1-score   support
#
#          Adressänderung       0.92      0.96      0.94        24
#         Auslandsbuchung       1.00      1.00      1.00        23
#       Bearbeitungsdauer       0.95      0.91      0.93        22
#                Gebühren       0.94      1.00      0.97        17
#           Gerätewechsel       1.00      0.95      0.98        22
#               Girokonto       0.96      1.00      0.98        24
#             Kreditkarte       0.96      0.96      0.96        27
# Nachhaltige Geldanlagen       0.95      0.95      0.95        19
#          Namensänderung       0.95      0.95      0.95        20
#                Phishing       1.00      0.95      0.97        20
#         Servicequalität       1.00      0.94      0.97        16
#           TAN-Verfahren       0.94      1.00      0.97        15
#
#                accuracy                           0.96       249
#               macro avg       0.96      0.96      0.96       249
#            weighted avg       0.96      0.96      0.96       249

# %%
# wrong classifications
df_results = pd.DataFrame({
    "text": x,
    "true": y,
    "pred": y_pred_loo
})
df_results[df_results["true"] != df_results["pred"]]
# Out:
#                                                   text  \
# 17   neues mobiltelefon gerne wissen nutzung sparka...
# 75   interessiere beantragung sparkassenkreditkarte...
# 96   denke darüber geld nachhaltig anzulegen empfeh...
# 111  vorgang scheint stocken geraten erklären wesha...
# 128  verständnis betrieb hätte zumindest zwischenme...
# 148  letzter besuch filiale leider enttäuschend mit...
# 169  versehentlich zugangsdaten gefälschten loginse...
# 224  name laura hofmann wohnortwechsel aktualisiere...
# 230  name bisher anna meier geheiratet trage namen ...
#
#                         true                     pred
# 17             Gerätewechsel              Kreditkarte
# 75               Kreditkarte                Girokonto
# 96   Nachhaltige Geldanlagen        Bearbeitungsdauer
# 111        Bearbeitungsdauer                 Gebühren
# 128        Bearbeitungsdauer  Nachhaltige Geldanlagen
# 148          Servicequalität            TAN-Verfahren
# 169                 Phishing           Adressänderung
# 224           Adressänderung           Namensänderung
# 230           Namensänderung           Adressänderung

# %%
# CM
labels = y.unique()
plt.figure(figsize=(10, 9))
sns.heatmap(confusion_matrix(y, y_pred_loo, labels=labels), annot=True, cmap='Greens',
            xticklabels=labels, yticklabels=labels)
plt.xlabel("pred")
plt.ylabel("true")
plt.title("CM Lin. Reg. LOO CV - LBFGS solver config")
plt.tight_layout()
plt.show()

# %%
# top words by coefficient
best_lr.fit(x, y)
vectorizer = best_lr.named_steps["tfidf"]
feature_names = np.array(vectorizer.get_feature_names_out())
lr_model = best_lr.named_steps["lr"]

for class_idx, class_label in enumerate(lr_model.classes_):
    coefs = lr_model.coef_[class_idx]
    top_pos_idx = np.argsort(coefs)[-10:]
    top_neg_idx = np.argsort(coefs)[:10]

    print(class_label)
    print("positive:")
    for i in reversed(top_pos_idx):
        print(f"{feature_names[i]:<20} {coefs[i]:.4f}")
    print("negative:")
    for i in top_neg_idx:
        print(f"{feature_names[i]:<20} {coefs[i]:.4f}")
# Out:
# Adressänderung
# positive:
# name                 3.2955
# adresse              2.2850
# geändert             1.8656
# umgezogen            1.5622
# neue                 1.5576
# aktualisieren        1.3808
# anschrift            1.3334
# julia                1.2391
# name julia           1.2391
# entsprechend         1.2379
# negative:
# wurde                -0.5898
# heiße                -0.5597
# konto                -0.5387
# gibt                 -0.5260
# namen                -0.5068
# sagen                -0.4675
# kreditkarte          -0.4338
# tanapp               -0.3774
# dafür                -0.3772
# heute                -0.3565
# Auslandsbuchung
# positive:
# abbuchung            2.6803
# zahlung              2.5433
# bestellt             2.2870
# transaktion          2.1350
# usdollar             1.8181
# kronen               1.7488
# betrag               1.4460
# anbieter             1.4317
# entdeckt             1.3952
# konto wurde          1.3581
# negative:
# gibt                 -0.6334
# sagen                -0.5528
# gebühren             -0.5293
# möchte               -0.5279
# kreditkarte          -0.4928
# tanapp               -0.4744
# erklären             -0.4612
# erhalten             -0.4551
# dafür                -0.4371
# anliegen             -0.4365
# Bearbeitungsdauer
# positive:
# anliegen             2.4636
# warte                2.1272
# lange                2.1230
# rückmeldung          2.0896
# warten               1.5673
# antwort              1.5232
# tagen                1.4181
# erwartet             1.3214
# warum                1.2475
# informieren          1.2464
# negative:
# wurde                -1.0072
# konto                -0.8047
# name                 -0.6750
# möchte               -0.6544
# kreditkarte          -0.6467
# heute                -0.5937
# gebühren             -0.5777
# tanapp               -0.5773
# mehr                 -0.5175
# dafür                -0.5122
# Gebühren
# positive:
# gebühren             3.7234
# kontoführungsgebühren 3.2914
# erklären             2.0161
# höhe                 1.9876
# konto                1.6364
# kontoauszug          1.5236
# hoch                 1.4902
# warum                1.2626
# inzwischen           1.2309
# ungewöhnlich         1.0785
# negative:
# name                 -0.5466
# kreditkarte          -0.5325
# gerne                -0.5074
# heute                -0.4789
# anliegen             -0.4586
# tanapp               -0.4506
# eröffnen             -0.4381
# prüfen               -0.4149
# onlinebanking        -0.4092
# sparkasse            -0.4031
# Gerätewechsel
# positive:
# neues                2.5411
# onlinebanking        2.4921
# smartphone           2.0051
# tanapp               1.8503
# handy                1.6812
# nutzen               1.5572
# gerät                1.5159
# einrichten           1.4935
# neues handy          1.2309
# aktivieren           1.1690
# negative:
# konto                -0.5749
# wurde                -0.5110
# name                 -0.5066
# kreditkarte          -0.4671
# sagen                -0.3825
# eröffnen             -0.3597
# interessiere         -0.3488
# sparkasse            -0.3327
# bereits              -0.3283
# gebühren             -0.3251
# Girokonto
# positive:
# eröffnen             3.2104
# dafür                2.3719
# girokonto            2.0938
# kontoeröffnung       1.7918
# girokonto eröffnen   1.6243
# eröffnung            1.4524
# sparkasse            1.4178
# sparkasse eröffnen   1.3571
# gerne                1.3107
# konto sparkasse      1.1815
# negative:
# kreditkarte          -0.7662
# wurde                -0.6135
# gibt                 -0.5952
# name                 -0.5418
# tanapp               -0.4911
# gebühren             -0.4762
# onlinebanking        -0.4433
# fonds                -0.4098
# heute                -0.4034
# mehr                 -0.3974
# Kreditkarte
# positive:
# kreditkarte          4.2924
# sparkassenkreditkarte 2.0971
# gibt                 1.9640
# beantragen           1.5495
# unterschiede         1.4858
# kreditkarte beantragen 1.4006
# interessiere         1.3233
# gerne                1.3119
# ausland              1.1445
# suche kreditkarte    1.1159
# negative:
# konto                -0.7676
# wurde                -0.6479
# name                 -0.6225
# eröffnen             -0.5942
# fonds                -0.5504
# tanapp               -0.5271
# girokonto            -0.5230
# anliegen             -0.5002
# neues                -0.4986
# nachhaltige          -0.4835
# Nachhaltige Geldanlagen
# positive:
# fonds                3.5780
# nachhaltige          2.8922
# thema                2.4256
# nachhaltigen         2.1464
# produkte             1.8597
# angebot              1.6015
# bietet               1.4228
# geldanlage           1.3589
# bereich              1.2321
# investieren          0.9825
# negative:
# kreditkarte          -0.6584
# konto                -0.6245
# wurde                -0.6042
# name                 -0.5592
# tanapp               -0.4406
# onlinebanking        -0.4082
# neues                -0.3917
# eröffnen             -0.3913
# heute                -0.3854
# mitteilen            -0.3801
# Namensänderung
# positive:
# heiße                2.5476
# namen                2.4652
# laura                1.9930
# paul                 1.6552
# mia                  1.6127
# max                  1.4717
# name                 1.4695
# hochzeit             1.3521
# bisheriger name      1.2916
# bisheriger           1.2916
# negative:
# adresse              -0.7432
# konto                -0.5552
# gibt                 -0.5365
# geändert             -0.5143
# sagen                -0.4527
# möchte               -0.4421
# kreditkarte          -0.4200
# heute                -0.3983
# umgezogen            -0.3896
# tanapp               -0.3781
# Phishing
# positive:
# link                 2.4629
# email                2.2633
# mail                 2.2219
# nachricht            2.0472
# adresse              1.9895
# erhalten             1.9158
# heute                1.8173
# geöffnet             1.7044
# eingegeben           1.4055
# absender             1.3436
# negative:
# name                 -0.6384
# gibt                 -0.5424
# tanapp               -0.4685
# sagen                -0.4650
# anliegen             -0.4571
# gebühren             -0.3786
# dafür                -0.3785
# mehr                 -0.3733
# zahlung              -0.3698
# gerne                -0.3492
# Servicequalität
# positive:
# wurde                3.6061
# gespräch             2.5647
# wirkte               1.8404
# wenig                1.8268
# fühlte               1.6717
# weder                1.6107
# kontakt              1.4159
# mehrfach             1.4127
# lösung               1.2616
# erklärung            1.2171
# negative:
# konto                -0.7363
# gibt                 -0.5913
# erhalten             -0.4996
# name                 -0.4946
# sagen                -0.4625
# kreditkarte          -0.4223
# tanapp               -0.4179
# prüfen               -0.3694
# daten                -0.3633
# onlinebanking        -0.3569
# TAN-Verfahren
# positive:
# tanapp               2.7597
# mehr                 2.6536
# beim                 1.8429
# bereits              1.7764
# app                  1.7493
# erscheint            1.5445
# funktioniert tanapp  1.3234
# fehlermeldung        1.3168
# bekomme              1.2137
# funktioniert         1.1495
# negative:
# wurde                -0.5571
# neues                -0.5310
# gibt                 -0.4604
# name                 -0.4575
# gerne                -0.3950
# kreditkarte          -0.3867
# mitteilen            -0.3610
# anliegen             -0.3595
# sparkasse            -0.3336
# dafür                -0.3251
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %% [markdown]
# # SVM

# %%
# Braucht ca. 4min
x_text = df_clean["Kundenanfrage"].astype(str)
y_labels = df_clean["Unterkategorie2"].astype(str)

# pipeline: combine TF-IDF and SVM
svm_loo_pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(
        max_features=1000,
        ngram_range=(1, 2),
        min_df=0.01,
        max_df=0.8
    )),
    ("svc", SVC())
])

svm_loo_params = {
    'svc__C': [0.1, 1, 10],
    'svc__kernel': ['linear', 'rbf'],
    'svc__class_weight': [None, 'balanced'],
    'svc__gamma': ['scale', 'auto']
}

loo_cv = LeaveOneOut()

svm_loo_grid = GridSearchCV(
    estimator=svm_loo_pipeline,
    param_grid=svm_loo_params,
    cv=loo_cv,
    scoring='accuracy',
    #scoring='f1-score',
    n_jobs=-1
)
svm_loo_grid.fit(x_text, y_labels)

best_svm_loo = svm_loo_grid.best_estimator_
print("best params:", svm_loo_grid.best_params_)
print("mean acc:", svm_loo_grid.best_score_)

y_pred_svm_loo = cross_val_predict(best_svm_loo, x_text, y_labels, cv=loo_cv, n_jobs=-1)
print(classification_report(y_labels, y_pred_svm_loo))

svm_loo_labels = y_labels.unique()
cm_svm_loo = confusion_matrix(y_labels, y_pred_svm_loo, labels=svm_loo_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_svm_loo, annot=True, fmt='d', cmap='Greens',
            xticklabels=svm_loo_labels, yticklabels=svm_loo_labels)
plt.xlabel("pred")
plt.ylabel("true")
plt.title("CM - SVM LOO config")
plt.tight_layout()
plt.show()
# Out:
# best params: {'svc__C': 1, 'svc__class_weight': None, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# mean acc: 0.963855421686747
#                          precision    recall  f1-score   support
#
#          Adressänderung       0.96      0.96      0.96        24
#         Auslandsbuchung       1.00      0.96      0.98        23
#       Bearbeitungsdauer       0.91      0.95      0.93        22
#                Gebühren       0.94      1.00      0.97        17
#           Gerätewechsel       1.00      0.95      0.98        22
#               Girokonto       0.96      0.96      0.96        24
#             Kreditkarte       0.93      1.00      0.96        27
# Nachhaltige Geldanlagen       1.00      0.89      0.94        19
#          Namensänderung       0.91      1.00      0.95        20
#                Phishing       1.00      0.95      0.97        20
#         Servicequalität       1.00      0.94      0.97        16
#           TAN-Verfahren       1.00      1.00      1.00        15
#
#                accuracy                           0.96       249
#               macro avg       0.97      0.96      0.96       249
#            weighted avg       0.97      0.96      0.96       249

# %%
# wrong classifications
df_results = pd.DataFrame({
    "text": x_text,
    "true": y_labels,
    "pred": y_pred_svm_loo
})

df_results[df_results["true"] != df_results["pred"]]
# Out:
#                                                   text  \
# 17   neues mobiltelefon gerne wissen nutzung sparka...
# 56   interessiere eröffnung girokontos sagen dafür ...
# 92   interesse ökologisch verantwortlichen investme...
# 96   denke darüber geld nachhaltig anzulegen empfeh...
# 111  vorgang scheint stocken geraten erklären wesha...
# 148  letzter besuch filiale leider enttäuschend mit...
# 169  versehentlich zugangsdaten gefälschten loginse...
# 204  name mia weber transaktion usa girokonto usa a...
# 224  name laura hofmann wohnortwechsel aktualisiere...
#
#                         true               pred
# 17             Gerätewechsel        Kreditkarte
# 56                 Girokonto        Kreditkarte
# 92   Nachhaltige Geldanlagen          Girokonto
# 96   Nachhaltige Geldanlagen  Bearbeitungsdauer
# 111        Bearbeitungsdauer           Gebühren
# 148          Servicequalität  Bearbeitungsdauer
# 169                 Phishing     Adressänderung
# 204          Auslandsbuchung     Namensänderung
# 224           Adressänderung     Namensänderung

# %%
# Support Vector Machines (with TF-IDF) and TRAIN TEST SPLIT
# as alternative to LO (but not really used in our work)

vectorizer = TfidfVectorizer( #same as before
    max_features=10000,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.9
)
x = vectorizer.fit_transform(df_clean["Kundenanfrage"])
y = df_clean["Unterkategorie2"]

y_encoded = LabelEncoder().fit_transform(y)
x_train, x_test, y_train, y_test = train_test_split(
    x, y_encoded, test_size=0.2
)

params1 = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'class_weight': [None, 'balanced']
}

svc = SVC()
grid = GridSearchCV(svc, params1, cv=5, scoring='accuracy', n_jobs=-1)
grid.fit(x_train, y_train)

best_svm = grid.best_estimator_
print("Best parameters:", grid.best_params_)

y_pred = best_svm.predict(x_test)
acc = accuracy_score(y_test, y_pred)

print("acc", acc)
print(classification_report(y_test, y_pred))
